# %% [markdown]
# # 0. Install and Import Dependencies

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %% [markdown]
# # 1. Make Some Detections

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.pose_landmarks
# Out:
# landmark {
#   x: 0.5206561088562012
#   y: 0.5016534328460693
#   z: -1.405130386352539
#   visibility: 0.9998446106910706
# }
# landmark {
#   x: 0.5547747611999512
#   y: 0.42790207266807556
#   z: -1.3164530992507935
#   visibility: 0.999654233455658
# }
# landmark {
#   x: 0.5773317217826843
#   y: 0.4300154149532318
#   z: -1.316960334777832
#   visibility: 0.9997344613075256
# }
# landmark {
#   x: 0.5981234312057495
#   y: 0.43295350670814514
#   z: -1.3170926570892334
#   visibility: 0.999589741230011
# }
# landmark {
#   x: 0.4832325577735901
#   y: 0.43119922280311584
#   z: -1.32487154006958
#   visibility: 0.99968421459198
# }
# landmark {
#   x: 0.45824599266052246
#   y: 0.43471184372901917
#   z: -1.3243218660354614
#   visibility: 0.9997680187225342
# }
# landmark {
#   x: 0.43616539239883423
#   y: 0.4387964904308319
#   z: -1.3250377178192139
#   visibility: 0.9997188448905945
# }
# landmark {
#   x: 0.6361509561538696
#   y: 0.48110702633857727
#   z: -0.7647455930709839
#   visibility: 0.9996932744979858
# }
# landmark {
#   x: 0.40649399161338806
#   y: 0.4834861755371094
#   z: -0.7798647880554199
#   visibility: 0.9998580813407898
# }
# landmark {
#   x: 0.568698525428772
#   y: 0.5923595428466797
#   z: -1.1966147422790527
#   visibility: 0.9998342394828796
# }
# landmark {
#   x: 0.4784300923347473
#   y: 0.5894647240638733
#   z: -1.2030094861984253
#   visibility: 0.9998990297317505
# }
# landmark {
#   x: 0.8107203245162964
#   y: 0.9158885478973389
#   z: -0.43593087792396545
#   visibility: 0.9958604574203491
# }
# landmark {
#   x: 0.23135590553283691
#   y: 0.904629111289978
#   z: -0.4928498864173889
#   visibility: 0.9965198040008545
# }
# landmark {
#   x: 0.9679940342903137
#   y: 1.3368384838104248
#   z: -0.6473638415336609
#   visibility: 0.46687600016593933
# }
# landmark {
#   x: 0.1156025305390358
#   y: 1.4088143110275269
#   z: -0.5570275187492371
#   visibility: 0.2787337303161621
# }
# landmark {
#   x: 0.9345895051956177
#   y: 1.7026344537734985
#   z: -1.3536274433135986
#   visibility: 0.5523762702941895
# }
# landmark {
#   x: 0.15851575136184692
#   y: 1.7889838218688965
#   z: -1.329498529434204
#   visibility: 0.17417806386947632
# }
# landmark {
#   x: 0.9491466283798218
#   y: 1.84247887134552
#   z: -1.5465785264968872
#   visibility: 0.5234087705612183
# }
# landmark {
#   x: 0.1458258330821991
#   y: 1.9362841844558716
#   z: -1.543355107307434
#   visibility: 0.20091478526592255
# }
# landmark {
#   x: 0.880622386932373
#   y: 1.8293260335922241
#   z: -1.62020742893219
#   visibility: 0.5551807880401611
# }
# landmark {
#   x: 0.2068966180086136
#   y: 1.9090518951416016
#   z: -1.6421549320220947
#   visibility: 0.3000466823577881
# }
# landmark {
#   x: 0.8575356602668762
#   y: 1.7729206085205078
#   z: -1.4170821905136108
#   visibility: 0.5302456617355347
# }
# landmark {
#   x: 0.22176766395568848
#   y: 1.852760672569275
#   z: -1.3972398042678833
#   visibility: 0.2723373770713806
# }
# landmark {
#   x: 0.709995687007904
#   y: 1.8703817129135132
#   z: -0.07898153364658356
#   visibility: 0.001862160861492157
# }
# landmark {
#   x: 0.33898964524269104
#   y: 1.876569151878357
#   z: 0.08614212274551392
#   visibility: 0.0010621498804539442
# }
# landmark {
#   x: 0.7150416374206543
#   y: 2.6521828174591064
#   z: -0.25812608003616333
#   visibility: 0.004661069251596928
# }
# landmark {
#   x: 0.3757540285587311
#   y: 2.6262502670288086
#   z: -0.2777602970600128
#   visibility: 0.0012181383790448308
# }
# landmark {
#   x: 0.7359298467636108
#   y: 3.34484601020813
#   z: 0.39041492342948914
#   visibility: 0.00016974529717117548
# }
# landmark {
#   x: 0.3980870246887207
#   y: 3.3279714584350586
#   z: 0.15797631442546844
#   visibility: 2.8591835871338844e-05
# }
# landmark {
#   x: 0.746957004070282
#   y: 3.4679877758026123
#   z: 0.4042116701602936
#   visibility: 0.00012902232992928475
# }
# landmark {
#   x: 0.3946916460990906
#   y: 3.4524741172790527
#   z: 0.1698703169822693
#   visibility: 6.605555972782895e-05
# }
# landmark {
#   x: 0.6764390468597412
#   y: 3.569119453430176
#   z: -0.42010027170181274
#   visibility: 0.0003086151264142245
# }
# landmark {
#   x: 0.4655323922634125
#   y: 3.5392391681671143
#   z: -0.6961185932159424
#   visibility: 0.0002957107499241829
# }

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %% [markdown]
# # 2. Capture Landmarks & Export to CSV
# <!--<img src="https://i.imgur.com/8bForKY.png">-->
# <img src="https://i.imgur.com/AzKNp7A.png">

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "Wakanda Forever "

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 3. Train Custom Model Using Scikit Learn

# %% [markdown]
# ## 3.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#    class        x1        y1        z1        v1        x2        y2  \
# 0  Happy  0.513519  0.501340 -0.807553  0.999938  0.549369  0.439245
# 1  Happy  0.513107  0.500544 -1.330617  0.999921  0.548526  0.432416
# 2  Happy  0.512285  0.500461 -1.426870  0.999897  0.547279  0.429787
# 3  Happy  0.511385  0.500380 -1.462211  0.999880  0.545434  0.428763
# 4  Happy  0.511634  0.500669 -1.497881  0.999843  0.545467  0.428304
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -0.757186  0.999832  0.572453  ...  0.000857   0.0  0.600867  0.442206
# 1 -1.251391  0.999787  0.572298  ...  0.000238   0.0  0.599176  0.441431
# 2 -1.345077  0.999730  0.571868  ... -0.001418   0.0  0.596903  0.438855
# 3 -1.381785  0.999689  0.570572  ... -0.001530   0.0  0.596921  0.439171
# 4 -1.413858  0.999601  0.570600  ... -0.001235   0.0  0.598918  0.440739
#
#        z500  v500      x501      y501      z501  v501
# 0  0.024949   0.0  0.607555  0.436299  0.025829   0.0
# 1  0.023234   0.0  0.606038  0.435103  0.023928   0.0
# 2  0.021571   0.0  0.603685  0.433256  0.022080   0.0
# 3  0.021571   0.0  0.603571  0.434075  0.022076   0.0
# 4  0.021818   0.0  0.605667  0.435448  0.022302   0.0
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#                 class        x1        y1        z1        v1        x2  \
# 867  Wakanda Forever   0.535607  0.540042 -0.647063  0.999620  0.558890
# 868  Wakanda Forever   0.534661  0.537595 -0.946406  0.999633  0.558649
# 869  Wakanda Forever   0.533456  0.533430 -0.940828  0.999657  0.558404
# 870  Wakanda Forever   0.533459  0.529844 -0.945225  0.999671  0.558376
# 871  Wakanda Forever   0.534163  0.529197 -0.915286  0.999674  0.558843
#
#            y2        z2        v2        x3  ...      z499  v499      x500  \
# 867  0.479877 -0.561291  0.999316  0.575288  ...  0.001063   0.0  0.595596
# 868  0.477417 -0.857635  0.999338  0.575164  ...  0.001660   0.0  0.598594
# 869  0.473868 -0.856076  0.999389  0.575157  ...  0.002945   0.0  0.600692
# 870  0.471358 -0.861413  0.999425  0.575182  ...  0.001661   0.0  0.609455
# 871  0.471203 -0.834749  0.999448  0.575917  ...  0.003818   0.0  0.621817
#
#          y500      z500  v500      x501      y501      z501  v501
# 867  0.486748  0.026991   0.0  0.601180  0.481623  0.028111   0.0
# 868  0.486991  0.028032   0.0  0.604091  0.481628  0.029240   0.0
# 869  0.483429  0.030572   0.0  0.606224  0.477916  0.031943   0.0
# 870  0.478662  0.027960   0.0  0.614931  0.472755  0.029271   0.0
# 871  0.483513  0.031923   0.0  0.627390  0.476899  0.033456   0.0
#
# [5 rows x 2005 columns]

# %%
df[df['class']=='Sad']
# Out:
#     class        x1        y1        z1        v1        x2        y2  \
# 160   Sad  0.535675  0.646818 -1.620482  0.999339  0.575090  0.560234
# 161   Sad  0.537756  0.645493 -1.612596  0.999370  0.576622  0.554398
# 162   Sad  0.537898  0.645198 -1.603285  0.999402  0.576744  0.552389
# 163   Sad  0.538044  0.644137 -1.594977  0.999429  0.576952  0.549379
# 164   Sad  0.537974  0.640841 -1.481017  0.999474  0.576947  0.546103
# ..    ...       ...       ...       ...       ...       ...       ...
# 350   Sad  0.509420  0.690459 -1.645796  0.998134  0.556280  0.588969
# 351   Sad  0.471314  0.690421 -1.695601  0.998179  0.520467  0.589683
# 352   Sad  0.436185  0.689726 -1.676526  0.997680  0.481976  0.590804
# 353   Sad  0.431568  0.683293 -1.771158  0.997385  0.477208  0.588657
# 354   Sad  0.406310  0.678498 -1.539029  0.993088  0.445122  0.586044
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 160 -1.574459  0.998188  0.597134  ... -0.028250   0.0  0.627523  0.555033
# 161 -1.562700  0.998273  0.598550  ... -0.030115   0.0  0.623116  0.561888
# 162 -1.554656  0.998366  0.598684  ... -0.028618   0.0  0.619132  0.558389
# 163 -1.543872  0.998448  0.598925  ... -0.029306   0.0  0.619846  0.557788
# 164 -1.424690  0.998569  0.598932  ... -0.028478   0.0  0.619473  0.559010
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 350 -1.624829  0.996166  0.583450  ... -0.046899   0.0  0.583269  0.629641
# 351 -1.697619  0.995927  0.551191  ... -0.050337   0.0  0.566257  0.624342
# 352 -1.713703  0.994235  0.513977  ... -0.045012   0.0  0.538123  0.623396
# 353 -1.791329  0.993506  0.509035  ... -0.044435   0.0  0.517999  0.622548
# 354 -1.570212  0.985781  0.473926  ... -0.044404   0.0  0.498775  0.600999
#
#          z500  v500      x501      y501      z501  v501
# 160 -0.007131   0.0  0.634272  0.548011 -0.007459   0.0
# 161 -0.009771   0.0  0.629408  0.555489 -0.010282   0.0
# 162 -0.009186   0.0  0.625443  0.552008 -0.009708   0.0
# 163 -0.009345   0.0  0.626173  0.551694 -0.009832   0.0
# 164 -0.008330   0.0  0.625840  0.552879 -0.008862   0.0
# ..        ...   ...       ...       ...       ...   ...
# 350 -0.043411   0.0  0.590963  0.620459 -0.045394   0.0
# 351 -0.055949   0.0  0.575929  0.609787 -0.058354   0.0
# 352 -0.057982   0.0  0.548113  0.610739 -0.061072   0.0
# 353 -0.059651   0.0  0.527216  0.612298 -0.062988   0.0
# 354 -0.072159   0.0  0.508960  0.587525 -0.076565   0.0
#
# [195 rows x 2005 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 160                 Sad
# 581    Wakanda Forever
# 484             Victory
# 480             Victory
# 830    Wakanda Forever
#              ...
# 28                Happy
# 865    Wakanda Forever
# 670    Wakanda Forever
# 73                Happy
# 411             Victory
# Name: class, Length: 262, dtype: object

# %% [markdown]
# ## 3.2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\Users\Dhaval Makvana\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Sad', 'Wakanda Forever ', 'Victory', 'Victory',
#        'Wakanda Forever ', 'Happy', 'Victory', 'Sad', 'Victory',
#        'Wakanda Forever ', 'Sad', 'Happy', 'Happy', 'Victory', 'Victory',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Victory', 'Victory',
#        'Wakanda Forever ', 'Sad', 'Sad', 'Wakanda Forever ', 'Victory',
#        'Sad', 'Wakanda Forever ', 'Happy', 'Wakanda Forever ', 'Happy',
#        'Sad', 'Wakanda Forever ', 'Sad', 'Happy', 'Wakanda Forever ',
#        'Sad', 'Victory', 'Wakanda Forever ', 'Wakanda Forever ', 'Sad',
#        'Victory', 'Wakanda Forever ', 'Victory', 'Victory', 'Sad',
#        'Victory', 'Sad', 'Victory', 'Sad', 'Sad', 'Wakanda Forever ',
#        'Happy', 'Sad', 'Sad', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Happy', 'Victory', 'Happy', 'Happy', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Victory', 'Happy', 'Happy', 'Victory', 'Wakanda Forever ', 'Sad',
#        'Victory', 'Happy', 'Wakanda Forever ', 'Sad', 'Wakanda Forever ',
#        'Sad', 'Sad', 'Wakanda Forever ', 'Wakanda Forever ', 'Happy',
#        'Wakanda Forever ', 'Victory', 'Victory', 'Victory',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Happy',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Sad', 'Wakanda Forever ',
#        'Victory', 'Happy', 'Wakanda Forever ', 'Happy',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Victory',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Sad', 'Happy',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Victory', 'Sad', 'Happy',
#        'Sad', 'Victory', 'Happy', 'Victory', 'Wakanda Forever ',
#        'Victory', 'Wakanda Forever ', 'Victory', 'Happy', 'Happy', 'Sad',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Happy', 'Wakanda Forever ', 'Victory',
#        'Wakanda Forever ', 'Happy', 'Happy', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Sad', 'Victory',
#        'Wakanda Forever ', 'Sad', 'Wakanda Forever ', 'Happy',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Victory', 'Sad', 'Sad',
#        'Sad', 'Wakanda Forever ', 'Happy', 'Happy', 'Sad', 'Sad', 'Sad',
#        'Sad', 'Wakanda Forever ', 'Happy', 'Happy', 'Wakanda Forever ',
#        'Victory', 'Victory', 'Wakanda Forever ', 'Happy', 'Sad',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Happy', 'Victory',
#        'Victory', 'Sad', 'Happy', 'Happy', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Sad', 'Victory', 'Victory',
#        'Wakanda Forever ', 'Sad', 'Victory', 'Sad', 'Victory', 'Sad',
#        'Happy', 'Sad', 'Happy', 'Victory', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Victory', 'Happy', 'Sad',
#        'Victory', 'Victory', 'Sad', 'Sad', 'Happy', 'Sad', 'Victory',
#        'Happy', 'Wakanda Forever ', 'Victory', 'Sad', 'Victory',
#        'Wakanda Forever ', 'Victory', 'Sad', 'Happy', 'Wakanda Forever ',
#        'Sad', 'Wakanda Forever ', 'Happy', 'Victory', 'Happy', 'Sad',
#        'Wakanda Forever ', 'Victory', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Victory', 'Sad', 'Happy', 'Happy', 'Happy',
#        'Happy', 'Victory', 'Happy', 'Victory', 'Happy', 'Sad', 'Sad',
#        'Happy', 'Victory', 'Victory', 'Happy', 'Sad', 'Happy', 'Sad',
#        'Victory', 'Wakanda Forever ', 'Sad', 'Sad', 'Sad',
#        'Wakanda Forever ', 'Sad', 'Victory', 'Sad', 'Victory', 'Victory',
#        'Sad', 'Wakanda Forever ', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Happy', 'Happy',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Happy', 'Victory'],
#       dtype='<U16')

# %% [markdown]
# ## 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9961832061068703
# rc 0.9961832061068703
# rf 1.0
# gb 0.9961832061068703

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Sad', 'Wakanda Forever ', 'Victory', 'Victory',
#        'Wakanda Forever ', 'Happy', 'Victory', 'Sad', 'Victory',
#        'Wakanda Forever ', 'Sad', 'Happy', 'Happy', 'Victory', 'Victory',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Victory', 'Victory',
#        'Wakanda Forever ', 'Sad', 'Sad', 'Wakanda Forever ', 'Victory',
#        'Sad', 'Wakanda Forever ', 'Happy', 'Wakanda Forever ', 'Happy',
#        'Sad', 'Wakanda Forever ', 'Sad', 'Happy', 'Wakanda Forever ',
#        'Sad', 'Victory', 'Wakanda Forever ', 'Wakanda Forever ', 'Sad',
#        'Victory', 'Wakanda Forever ', 'Victory', 'Victory', 'Sad',
#        'Victory', 'Sad', 'Victory', 'Sad', 'Sad', 'Wakanda Forever ',
#        'Happy', 'Sad', 'Sad', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Happy', 'Victory', 'Happy', 'Happy', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Victory', 'Happy', 'Happy', 'Victory', 'Wakanda Forever ', 'Sad',
#        'Victory', 'Happy', 'Wakanda Forever ', 'Sad', 'Wakanda Forever ',
#        'Sad', 'Sad', 'Wakanda Forever ', 'Wakanda Forever ', 'Happy',
#        'Wakanda Forever ', 'Victory', 'Victory', 'Victory',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Happy',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Sad', 'Wakanda Forever ',
#        'Victory', 'Happy', 'Wakanda Forever ', 'Happy',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Victory',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Sad', 'Happy',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Victory', 'Sad', 'Happy',
#        'Sad', 'Victory', 'Happy', 'Victory', 'Wakanda Forever ',
#        'Victory', 'Wakanda Forever ', 'Victory', 'Happy', 'Happy', 'Sad',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Happy', 'Wakanda Forever ', 'Victory',
#        'Wakanda Forever ', 'Happy', 'Happy', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Sad', 'Victory',
#        'Wakanda Forever ', 'Sad', 'Wakanda Forever ', 'Happy',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Victory', 'Sad', 'Sad',
#        'Sad', 'Wakanda Forever ', 'Happy', 'Happy', 'Sad', 'Sad', 'Sad',
#        'Sad', 'Wakanda Forever ', 'Happy', 'Happy', 'Wakanda Forever ',
#        'Victory', 'Victory', 'Wakanda Forever ', 'Happy', 'Sad',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Happy', 'Victory',
#        'Victory', 'Sad', 'Happy', 'Happy', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Sad', 'Wakanda Forever ', 'Victory',
#        'Wakanda Forever ', 'Sad', 'Victory', 'Sad', 'Victory', 'Sad',
#        'Happy', 'Sad', 'Happy', 'Victory', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Victory', 'Happy', 'Sad',
#        'Victory', 'Victory', 'Sad', 'Sad', 'Happy', 'Sad', 'Victory',
#        'Happy', 'Wakanda Forever ', 'Victory', 'Sad', 'Victory',
#        'Wakanda Forever ', 'Victory', 'Sad', 'Happy', 'Wakanda Forever ',
#        'Sad', 'Wakanda Forever ', 'Happy', 'Victory', 'Happy', 'Sad',
#        'Wakanda Forever ', 'Victory', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Victory', 'Sad', 'Happy', 'Happy', 'Happy',
#        'Happy', 'Victory', 'Happy', 'Victory', 'Happy', 'Sad', 'Sad',
#        'Happy', 'Victory', 'Victory', 'Happy', 'Sad', 'Happy', 'Sad',
#        'Victory', 'Wakanda Forever ', 'Sad', 'Sad', 'Sad',
#        'Wakanda Forever ', 'Sad', 'Victory', 'Sad', 'Victory', 'Victory',
#        'Sad', 'Wakanda Forever ', 'Wakanda Forever ', 'Wakanda Forever ',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Happy', 'Happy',
#        'Wakanda Forever ', 'Wakanda Forever ', 'Happy', 'Victory'],
#       dtype=object)

# %%
y_test
# Out:
# 160                 Sad
# 581    Wakanda Forever
# 484             Victory
# 480             Victory
# 830    Wakanda Forever
#              ...
# 28                Happy
# 865    Wakanda Forever
# 670    Wakanda Forever
# 73                Happy
# 411             Victory
# Name: class, Length: 262, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # 4. Make Detections with Model

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Happy [0.45 0.   0.42 0.13]
# Happy [0.73 0.   0.17 0.1 ]
# Happy [0.77 0.   0.17 0.06]
# Happy [0.71 0.   0.2  0.09]
# Happy [0.69 0.   0.2  0.11]
# Happy [0.71 0.   0.18 0.11]
# Happy [0.72 0.   0.18 0.1 ]
# Happy [0.72 0.   0.17 0.11]
# Happy [0.74 0.   0.15 0.11]
# Happy [0.83 0.   0.12 0.05]
# Happy [0.82 0.   0.12 0.06]
# Happy [0.73 0.   0.17 0.1 ]
# Happy [0.73 0.   0.17 0.1 ]
# Happy [0.66 0.   0.27 0.07]
# Happy [0.7 0.  0.2 0.1]
# Happy [0.7 0.  0.2 0.1]
# Happy [0.73 0.   0.19 0.08]
# Happy [0.79 0.   0.13 0.08]
# Happy [0.74 0.   0.2  0.06]
# Happy [0.69 0.   0.22 0.09]
# Happy [0.67 0.   0.26 0.07]
# Happy [0.6  0.   0.16 0.24]
# Victory [0.23 0.15 0.53 0.09]
# Victory [0.13 0.38 0.42 0.07]
# Sad [0.04 0.78 0.18 0.  ]
# Sad [0.03 0.88 0.09 0.  ]
# Sad [0.   0.95 0.05 0.  ]
# Sad [0.   0.97 0.03 0.  ]
# Sad [0.   0.97 0.03 0.  ]
# Sad [0.   0.97 0.03 0.  ]
# Sad [0.   0.97 0.03 0.  ]
# Sad [0.   0.96 0.04 0.  ]
# Sad [0.   0.96 0.04 0.  ]
# Sad [0.   0.96 0.04 0.  ]
# Sad [0.   0.96 0.04 0.  ]
# Sad [0.   0.96 0.04 0.  ]
# Sad [0.   0.96 0.04 0.  ]
# Sad [0.   0.96 0.04 0.  ]
# Sad [0.02 0.92 0.06 0.  ]
# Sad [0.02 0.9  0.08 0.  ]
# Sad [0.02 0.89 0.09 0.  ]
# Sad [0.03 0.87 0.1  0.  ]
# Sad [0.03 0.86 0.11 0.  ]
# Sad [0.05 0.7  0.24 0.01]
# Sad [0.1  0.43 0.42 0.05]
# Victory [0.17 0.27 0.5  0.06]
# Victory [0.18 0.2  0.54 0.08]
# Victory [0.2  0.16 0.56 0.08]
# Victory [0.21 0.15 0.56 0.08]
# Victory [0.28 0.1  0.54 0.08]
# Victory [0.28 0.1  0.55 0.07]
# Victory [0.29 0.1  0.54 0.07]
# Victory [0.31 0.1  0.51 0.08]
# Victory [0.31 0.1  0.5  0.09]
# Victory [0.34 0.1  0.47 0.09]
# Victory [0.36 0.1  0.45 0.09]
# Victory [0.35 0.1  0.46 0.09]
# Victory [0.34 0.1  0.45 0.11]
# Happy [0.41 0.1  0.32 0.17]
# Happy [0.44 0.01 0.31 0.24]
# Victory [0.33 0.   0.44 0.23]
# Victory [0.21 0.   0.56 0.23]
# Victory [0.12 0.   0.7  0.18]
# Victory [0.09 0.   0.72 0.19]
# Victory [0.07 0.   0.82 0.11]
# Victory [0.04 0.   0.87 0.09]
# Victory [0.03 0.   0.86 0.11]
# Victory [0.03 0.   0.86 0.11]
# Victory [0.03 0.   0.96 0.01]
# Victory [0.03 0.   0.96 0.01]
# Victory [0.02 0.   0.98 0.  ]
# Victory [0.02 0.   0.98 0.  ]
# Victory [0.02 0.   0.98 0.  ]
# Victory [0.01 0.   0.99 0.  ]
# Victory [0.01 0.   0.99 0.  ]
# Victory [0.01 0.   0.99 0.  ]
# Victory [0.02 0.   0.98 0.  ]
# Victory [0.02 0.   0.96 0.02]
# Victory [0.05 0.   0.92 0.03]
# Victory [0.1  0.   0.85 0.05]
# Victory [0.09 0.   0.87 0.04]
# Victory [0.1  0.   0.87 0.03]
# Victory [0.11 0.   0.83 0.06]
# Victory [0.09 0.   0.64 0.27]
# Victory [0.11 0.   0.58 0.31]
# Victory [0.1  0.   0.56 0.34]
# Victory [0.14 0.   0.53 0.33]
# Happy [0.41 0.   0.39 0.2 ]
# Victory [0.18 0.   0.52 0.3 ]
# Victory [0.27 0.   0.48 0.25]
# Victory [0.37 0.   0.4  0.23]
# Victory [0.38 0.   0.41 0.21]
# Victory [0.3  0.   0.44 0.26]
# Victory [0.29 0.   0.42 0.29]
# Victory [0.15 0.01 0.47 0.37]
# Victory [0.16 0.01 0.49 0.34]
# Victory [0.16 0.01 0.48 0.35]
# Victory [0.17 0.01 0.49 0.33]
# Victory [0.11 0.   0.69 0.2 ]
# Victory [0.11 0.   0.69 0.2 ]
# Victory [0.12 0.01 0.68 0.19]
# Victory [0.3  0.01 0.42 0.27]
# Victory [0.18 0.01 0.44 0.37]
# Victory [0.17 0.01 0.46 0.36]
# Victory [0.25 0.   0.46 0.29]
# Victory [0.27 0.   0.48 0.25]
# Victory [0.31 0.   0.41 0.28]
# Victory [0.21 0.   0.43 0.36]
# Victory [0.23 0.01 0.4  0.36]
# Victory [0.22 0.01 0.39 0.38]
# Victory [0.22 0.01 0.39 0.38]
# Victory [0.22 0.01 0.4  0.37]
# Victory [0.22 0.01 0.4  0.37]
# Victory [0.25 0.   0.4  0.35]
# Victory [0.23 0.01 0.39 0.37]
# Victory [0.25 0.   0.39 0.36]
# Victory [0.23 0.01 0.39 0.37]
# Victory [0.3  0.   0.36 0.34]
# Victory [0.28 0.   0.36 0.36]
# Victory [0.2  0.01 0.41 0.38]
# Happy [0.38 0.   0.3  0.32]
# Victory [0.32 0.   0.38 0.3 ]
# Victory [0.34 0.03 0.35 0.28]
# Victory [0.22 0.01 0.42 0.35]
# Wakanda Forever  [0.22 0.01 0.37 0.4 ]
# Victory [0.24 0.   0.41 0.35]
# Victory [0.23 0.01 0.42 0.34]
# Victory [0.23 0.01 0.41 0.35]
# Victory [0.23 0.01 0.41 0.35]
# Victory [0.23 0.01 0.41 0.35]
# Victory [0.23 0.01 0.41 0.35]
# Victory [0.27 0.   0.38 0.35]
# Victory [0.23 0.01 0.42 0.34]
# Victory [0.24 0.01 0.41 0.34]
# Victory [0.24 0.01 0.4  0.35]
# Victory [0.22 0.01 0.41 0.36]
# Victory [0.23 0.01 0.38 0.38]
# Victory [0.24 0.01 0.38 0.37]
# Victory [0.24 0.   0.38 0.38]
# Victory [0.18 0.03 0.58 0.21]
# Victory [0.13 0.02 0.53 0.32]
# Victory [0.23 0.02 0.39 0.36]
# Wakanda Forever  [0.19 0.01 0.39 0.41]
# Victory [0.21 0.01 0.39 0.39]
# Victory [0.21 0.01 0.4  0.38]
# Victory [0.2  0.01 0.48 0.31]
# Victory [0.16 0.01 0.53 0.3 ]
# Victory [0.17 0.01 0.45 0.37]
# Victory [0.2  0.01 0.43 0.36]
# Victory [0.29 0.01 0.39 0.31]
# Victory [0.2  0.01 0.41 0.38]
# Victory [0.18 0.01 0.43 0.38]
# Victory [0.18 0.01 0.44 0.37]
# Victory [0.19 0.01 0.43 0.37]
# Victory [0.19 0.01 0.45 0.35]
# Wakanda Forever  [0.16 0.01 0.41 0.42]
# Victory [0.07 0.14 0.63 0.16]
# Victory [0.1  0.03 0.69 0.18]
# Victory [0.26 0.02 0.43 0.29]
# Victory [0.27 0.01 0.41 0.31]
# Victory [0.18 0.01 0.43 0.38]
# Victory [0.16 0.01 0.43 0.4 ]
# Victory [0.17 0.   0.44 0.39]
# Victory [0.16 0.   0.45 0.39]
# Victory [0.15 0.   0.46 0.39]
# Victory [0.17 0.   0.44 0.39]
# Victory [0.17 0.   0.43 0.4 ]
# Victory [0.17 0.   0.44 0.39]
# Victory [0.2  0.   0.45 0.35]
# Victory [0.19 0.01 0.44 0.36]
# Victory [0.24 0.   0.43 0.33]
# Victory [0.18 0.01 0.52 0.29]
# Victory [0.24 0.01 0.44 0.31]
# Victory [0.18 0.01 0.62 0.19]
# Victory [0.18 0.01 0.6  0.21]
# Victory [0.17 0.01 0.65 0.17]
# Victory [0.17 0.02 0.63 0.18]
# Victory [0.2  0.02 0.57 0.21]
# Victory [0.18 0.02 0.59 0.21]
# Victory [0.16 0.02 0.62 0.2 ]
# Victory [0.16 0.02 0.65 0.17]
# Victory [0.19 0.02 0.6  0.19]
# Victory [0.19 0.02 0.61 0.18]
# Victory [0.19 0.02 0.61 0.18]
# Victory [0.18 0.02 0.65 0.15]
# Victory [0.17 0.03 0.66 0.14]
# Victory [0.17 0.03 0.67 0.13]
# Victory [0.17 0.02 0.68 0.13]
# Victory [0.15 0.03 0.69 0.13]
# Victory [0.15 0.03 0.7  0.12]
# Victory [0.15 0.01 0.69 0.15]
# Victory [0.14 0.02 0.7  0.14]
# Victory [0.13 0.02 0.69 0.16]
# Victory [0.2  0.02 0.61 0.17]
# Victory [0.27 0.   0.4  0.33]
# Victory [0.31 0.02 0.34 0.33]
# Victory [0.26 0.01 0.37 0.36]
# Victory [0.22 0.   0.39 0.39]
# Victory [0.23 0.   0.4  0.37]
# Victory [0.23 0.   0.4  0.37]
# Victory [0.21 0.   0.4  0.39]
# Victory [0.21 0.   0.42 0.37]
# Victory [0.21 0.   0.42 0.37]
# Victory [0.21 0.   0.42 0.37]
# Victory [0.21 0.   0.41 0.38]
# Victory [0.11 0.   0.63 0.26]
# Victory [0.1  0.01 0.67 0.22]
# Victory [0.13 0.01 0.65 0.21]
# Victory [0.13 0.01 0.61 0.25]
# Victory [0.15 0.01 0.63 0.21]
# Victory [0.19 0.01 0.56 0.24]
# Victory [0.19 0.01 0.51 0.29]
# Victory [0.19 0.01 0.53 0.27]
# Victory [0.18 0.01 0.59 0.22]
# Victory [0.18 0.01 0.59 0.22]
# Victory [0.19 0.02 0.6  0.19]
# Victory [0.2  0.01 0.6  0.19]
# Victory [0.16 0.01 0.66 0.17]
# Victory [0.21 0.03 0.63 0.13]
# Victory [0.2  0.01 0.66 0.13]
# Victory [0.14 0.01 0.68 0.17]
# Victory [0.16 0.02 0.67 0.15]
# Victory [0.16 0.   0.7  0.14]
# Victory [0.12 0.01 0.75 0.12]
# Victory [0.12 0.02 0.75 0.11]
# Victory [0.14 0.02 0.73 0.11]
# Victory [0.14 0.03 0.73 0.1 ]
# Victory [0.16 0.03 0.71 0.1 ]
# Victory [0.17 0.01 0.71 0.11]
# Victory [0.17 0.02 0.7  0.11]
# Victory [0.15 0.02 0.74 0.09]
# Victory [0.11 0.02 0.8  0.07]
# Victory [0.12 0.03 0.78 0.07]
# Victory [0.1  0.03 0.8  0.07]
# Victory [0.1  0.03 0.8  0.07]
# Victory [0.12 0.04 0.78 0.06]
# Victory [0.12 0.03 0.77 0.08]
# Victory [0.12 0.03 0.78 0.07]
# Victory [0.13 0.03 0.77 0.07]
# Victory [0.1  0.03 0.8  0.07]
# Victory [0.09 0.03 0.8  0.08]
# Victory [0.08 0.04 0.81 0.07]
# Victory [0.12 0.03 0.77 0.08]
# Victory [0.09 0.03 0.8  0.08]
# Victory [0.12 0.03 0.77 0.08]
# Victory [0.11 0.05 0.76 0.08]
# Victory [0.1  0.03 0.8  0.07]
# Victory [0.1  0.03 0.81 0.06]
# Victory [0.09 0.01 0.85 0.05]
# Victory [0.07 0.01 0.87 0.05]
# Victory [0.09 0.01 0.85 0.05]
# Victory [0.1  0.01 0.84 0.05]
# Victory [0.1  0.01 0.84 0.05]
# Victory [0.1  0.01 0.83 0.06]
# Victory [0.1  0.   0.84 0.06]
# Victory [0.1  0.   0.84 0.06]
# Victory [0.1  0.02 0.82 0.06]
# Victory [0.11 0.01 0.82 0.06]
# Victory [0.06 0.08 0.81 0.05]
# Victory [0.08 0.21 0.64 0.07]
# Victory [0.1  0.04 0.73 0.13]
# Victory [0.1  0.04 0.71 0.15]
# Victory [0.1  0.03 0.71 0.16]
# Victory [0.25 0.01 0.41 0.33]
# Victory [0.2  0.01 0.43 0.36]
# Victory [0.19 0.01 0.46 0.34]
# Victory [0.18 0.01 0.47 0.34]
# Victory [0.2  0.01 0.43 0.36]
# Victory [0.21 0.01 0.43 0.35]
# Victory [0.2  0.01 0.41 0.38]
# Victory [0.15 0.01 0.63 0.21]
# Victory [0.18 0.01 0.61 0.2 ]
# Victory [0.18 0.01 0.57 0.24]
# Victory [0.21 0.01 0.44 0.34]
# Victory [0.23 0.01 0.41 0.35]
# Victory [0.17 0.01 0.57 0.25]
# Victory [0.17 0.01 0.6  0.22]
# Victory [0.15 0.01 0.63 0.21]
# Victory [0.17 0.01 0.63 0.19]
# Victory [0.13 0.01 0.71 0.15]
# Victory [0.13 0.02 0.7  0.15]
# Victory [0.13 0.02 0.7  0.15]
# Victory [0.12 0.02 0.7  0.16]
# Victory [0.12 0.02 0.7  0.16]
# Victory [0.12 0.03 0.69 0.16]
# Victory [0.14 0.02 0.67 0.17]
# Victory [0.13 0.02 0.69 0.16]
# Victory [0.13 0.02 0.69 0.16]
# Victory [0.14 0.02 0.71 0.13]
# Victory [0.14 0.02 0.71 0.13]
# Victory [0.14 0.02 0.74 0.1 ]
# Victory [0.13 0.02 0.76 0.09]
# Victory [0.13 0.03 0.75 0.09]
# Victory [0.11 0.1  0.7  0.09]
# Victory [0.11 0.08 0.72 0.09]
# Victory [0.13 0.01 0.76 0.1 ]
# Victory [0.14 0.02 0.75 0.09]
# Victory [0.17 0.02 0.74 0.07]
# Victory [0.18 0.02 0.73 0.07]
# Victory [0.18 0.01 0.73 0.08]
# Victory [0.17 0.   0.76 0.07]
# Victory [0.18 0.   0.75 0.07]
# Victory [0.13 0.   0.78 0.09]
# Victory [0.11 0.   0.77 0.12]
# Victory [0.05 0.   0.84 0.11]
# Victory [0.04 0.01 0.81 0.14]
# Victory [0.06 0.01 0.84 0.09]
# Victory [0.09 0.01 0.81 0.09]
# Victory [0.1  0.01 0.8  0.09]
# Victory [0.09 0.01 0.77 0.13]
# Victory [0.11 0.01 0.73 0.15]
# Victory [0.13 0.03 0.71 0.13]
# Victory [0.11 0.08 0.7  0.11]
# Victory [0.08 0.01 0.79 0.12]
# Victory [0.09 0.05 0.72 0.14]
# Victory [0.09 0.02 0.74 0.15]
# Victory [0.07 0.01 0.77 0.15]
# Victory [0.07 0.01 0.71 0.21]
# Victory [0.06 0.05 0.7  0.19]
# Victory [0.05 0.08 0.69 0.18]
# Victory [0.05 0.05 0.72 0.18]
# Victory [0.09 0.01 0.74 0.16]
# Victory [0.05 0.07 0.73 0.15]
# Victory [0.11 0.01 0.77 0.11]
# Victory [0.11 0.02 0.78 0.09]
# Victory [0.17 0.01 0.72 0.1 ]
# Victory [0.22 0.01 0.69 0.08]
# Victory [0.23 0.01 0.67 0.09]
# Victory [0.22 0.01 0.69 0.08]
# Victory [0.23 0.01 0.69 0.07]
# Victory [0.21 0.01 0.71 0.07]
# Victory [0.2  0.01 0.72 0.07]
# Victory [0.19 0.01 0.73 0.07]
# Victory [0.14 0.01 0.75 0.1 ]
# Victory [0.13 0.01 0.79 0.07]
# Victory [0.1  0.01 0.77 0.12]
# Victory [0.08 0.   0.82 0.1 ]
# Victory [0.07 0.   0.8  0.13]
# Victory [0.06 0.   0.7  0.24]
# Victory [0.08 0.   0.68 0.24]
# Victory [0.06 0.   0.72 0.22]
# Victory [0.05 0.   0.74 0.21]
# Victory [0.05 0.   0.73 0.22]
# Victory [0.03 0.   0.81 0.16]
# Victory [0.09 0.   0.75 0.16]
# Victory [0.09 0.   0.78 0.13]
# Victory [0.11 0.   0.77 0.12]
# Victory [0.1  0.   0.81 0.09]
# Victory [0.1  0.   0.81 0.09]
# Victory [0.1  0.01 0.78 0.11]
# Victory [0.07 0.03 0.8  0.1 ]
# Victory [0.08 0.01 0.81 0.1 ]
# Victory [0.07 0.19 0.66 0.08]
# Victory [0.06 0.1  0.76 0.08]
# Victory [0.07 0.05 0.8  0.08]
# Victory [0.07 0.02 0.83 0.08]
# Victory [0.08 0.   0.84 0.08]
# Victory [0.07 0.02 0.81 0.1 ]
# Victory [0.08 0.03 0.8  0.09]
# Victory [0.07 0.04 0.8  0.09]
# Victory [0.06 0.11 0.74 0.09]
# Victory [0.08 0.11 0.72 0.09]
# Sad [0.01 0.72 0.24 0.03]
# Sad [0.01 0.67 0.29 0.03]
# Victory [0.06 0.16 0.7  0.08]
# Victory [0.07 0.17 0.68 0.08]
# Victory [0.07 0.21 0.64 0.08]
# Victory [0.05 0.2  0.67 0.08]
# Victory [0.07 0.19 0.66 0.08]
# Sad [0.03 0.46 0.45 0.06]
# Sad [0.   0.87 0.09 0.04]
# Sad [0.   0.87 0.09 0.04]
# Sad [0.   0.87 0.09 0.04]
# Sad [0.01 0.82 0.13 0.04]
# Sad [0.02 0.57 0.33 0.08]
# Victory [0.07 0.31 0.5  0.12]
# Victory [0.08 0.26 0.51 0.15]
# Victory [0.09 0.12 0.64 0.15]
# Victory [0.09 0.15 0.61 0.15]
# Victory [0.1  0.08 0.66 0.16]
# Victory [0.11 0.04 0.69 0.16]
# Victory [0.15 0.01 0.68 0.16]
# Victory [0.15 0.02 0.64 0.19]
# Victory [0.07 0.   0.7  0.23]
# Victory [0.05 0.   0.69 0.26]
# Victory [0.06 0.   0.68 0.26]
# Victory [0.07 0.   0.84 0.09]
# Victory [0.08 0.01 0.78 0.13]
# Victory [0.07 0.01 0.74 0.18]
# Victory [0.06 0.01 0.72 0.21]
# Victory [0.07 0.01 0.74 0.18]
# Victory [0.06 0.01 0.76 0.17]
# Victory [0.08 0.08 0.72 0.12]
# Victory [0.08 0.1  0.63 0.19]
# Victory [0.09 0.02 0.7  0.19]
# Victory [0.1  0.01 0.69 0.2 ]
# Victory [0.09 0.02 0.7  0.19]
# Victory [0.1  0.02 0.7  0.18]
# Victory [0.09 0.02 0.69 0.2 ]
# Victory [0.09 0.03 0.68 0.2 ]
# Victory [0.08 0.08 0.65 0.19]
# Victory [0.08 0.11 0.6  0.21]
# Victory [0.08 0.11 0.61 0.2 ]
# Victory [0.08 0.11 0.62 0.19]
# Victory [0.11 0.1  0.58 0.21]
# Victory [0.1  0.11 0.57 0.22]
# Victory [0.1  0.1  0.56 0.24]
# Victory [0.1  0.1  0.58 0.22]
# Victory [0.08 0.05 0.66 0.21]
# Victory [0.07 0.02 0.71 0.2 ]
# Victory [0.07 0.02 0.72 0.19]
# Victory [0.07 0.02 0.73 0.18]
# Victory [0.08 0.01 0.73 0.18]
# Victory [0.09 0.   0.82 0.09]
# Victory [0.07 0.   0.82 0.11]
# Victory [0.05 0.   0.81 0.14]
# Victory [0.04 0.   0.84 0.12]
# Victory [0.09 0.02 0.8  0.09]
# Victory [0.09 0.04 0.79 0.08]
# Victory [0.09 0.06 0.73 0.12]
# Victory [0.12 0.06 0.7  0.12]
# Victory [0.11 0.07 0.71 0.11]
# Wakanda Forever  [0.15 0.01 0.33 0.51]
# Victory [0.08 0.07 0.68 0.17]
# Victory [0.16 0.07 0.47 0.3 ]
# Victory [0.16 0.02 0.61 0.21]
# Victory [0.12 0.   0.49 0.39]
# Victory [0.05 0.01 0.67 0.27]
# Victory [0.04 0.02 0.64 0.3 ]
# Victory [0.03 0.   0.67 0.3 ]
# Victory [0.03 0.   0.67 0.3 ]
# Victory [0.03 0.   0.67 0.3 ]
# Victory [0.02 0.   0.67 0.31]
# Victory [0.02 0.   0.68 0.3 ]
# Victory [0.03 0.   0.67 0.3 ]
# Victory [0.03 0.   0.67 0.3 ]
# Wakanda Forever  [0.08 0.   0.45 0.47]
# Victory [0.09 0.   0.5  0.41]
# Victory [0.08 0.   0.56 0.36]
# Victory [0.07 0.   0.62 0.31]
# Victory [0.08 0.   0.6  0.32]
# Victory [0.08 0.   0.6  0.32]
# Victory [0.13 0.   0.63 0.24]
# Victory [0.15 0.01 0.63 0.21]
# Victory [0.09 0.08 0.66 0.17]
# Victory [0.09 0.06 0.7  0.15]
# Victory [0.11 0.08 0.64 0.17]
# Victory [0.12 0.08 0.65 0.15]
# Victory [0.08 0.08 0.7  0.14]
# Victory [0.09 0.08 0.69 0.14]
# Victory [0.09 0.08 0.69 0.14]
# Victory [0.09 0.08 0.67 0.16]
# Victory [0.09 0.08 0.64 0.19]
# Victory [0.14 0.09 0.6  0.17]
# Victory [0.12 0.09 0.61 0.18]
# Victory [0.11 0.08 0.63 0.18]
# Victory [0.1  0.01 0.73 0.16]
# Victory [0.1  0.06 0.69 0.15]
# Victory [0.09 0.06 0.7  0.15]
# Victory [0.11 0.08 0.69 0.12]
# Victory [0.11 0.08 0.67 0.14]
# Victory [0.1  0.03 0.73 0.14]
# Victory [0.12 0.03 0.69 0.16]
# Victory [0.1  0.02 0.74 0.14]
# Victory [0.11 0.06 0.68 0.15]
# Victory [0.14 0.03 0.69 0.14]
# Victory [0.15 0.03 0.68 0.14]
# Victory [0.13 0.1  0.63 0.14]
# Victory [0.14 0.09 0.64 0.13]
# Victory [0.14 0.09 0.64 0.13]
# Victory [0.17 0.03 0.64 0.16]
# Victory [0.14 0.09 0.62 0.15]
# Victory [0.15 0.03 0.68 0.14]
# Victory [0.16 0.03 0.67 0.14]
# Happy [0.37 0.   0.33 0.3 ]
# Victory [0.22 0.   0.49 0.29]
# Victory [0.06 0.01 0.82 0.11]
# Victory [0.03 0.   0.9  0.07]
# Victory [0.03 0.   0.86 0.11]
# Victory [0.03 0.   0.79 0.18]
# Victory [0.03 0.   0.82 0.15]
# Victory [0.03 0.   0.83 0.14]
# Victory [0.03 0.   0.83 0.14]
# Victory [0.02 0.   0.86 0.12]
# Victory [0.01 0.   0.88 0.11]
# Victory [0.01 0.   0.88 0.11]
# Victory [0.01 0.   0.88 0.11]
# Victory [0.01 0.   0.85 0.14]
# Victory [0.01 0.   0.84 0.15]
# Victory [0.01 0.   0.83 0.16]
# Victory [0.01 0.   0.82 0.17]
# Victory [0.01 0.   0.82 0.17]
# Victory [0.01 0.   0.82 0.17]
# Victory [0.01 0.   0.81 0.18]
# Victory [0.01 0.   0.81 0.18]
# Victory [0.01 0.   0.81 0.18]
# Victory [0.01 0.   0.81 0.18]
# Victory [0.01 0.   0.81 0.18]
# Victory [0.01 0.   0.82 0.17]
# Victory [0.01 0.   0.82 0.17]
# Victory [0.05 0.   0.69 0.26]
# Wakanda Forever  [0.28 0.01 0.29 0.42]
# Happy [0.36 0.01 0.33 0.3 ]
# Victory [0.22 0.08 0.42 0.28]
# Victory [0.12 0.08 0.51 0.29]
# Victory [0.16 0.06 0.46 0.32]
# Victory [0.19 0.06 0.46 0.29]
# Victory [0.25 0.01 0.43 0.31]
# Victory [0.29 0.01 0.42 0.28]
# Victory [0.33 0.   0.43 0.24]
# Victory [0.16 0.   0.55 0.29]
# Victory [0.05 0.01 0.77 0.17]
# Victory [0.17 0.08 0.48 0.27]
# Victory [0.32 0.08 0.46 0.14]
# Victory [0.27 0.08 0.48 0.17]
# Victory [0.35 0.04 0.42 0.19]
# Victory [0.35 0.   0.5  0.15]
# Wakanda Forever  [0.05 0.   0.38 0.57]
# Wakanda Forever  [0.   0.   0.25 0.75]
# Wakanda Forever  [0.02 0.   0.26 0.72]
# Wakanda Forever  [0.03 0.   0.26 0.71]
# Wakanda Forever  [0.09 0.   0.38 0.53]
# Wakanda Forever  [0.15 0.   0.27 0.58]
# Wakanda Forever  [0.04 0.   0.21 0.75]
# Wakanda Forever  [0.14 0.   0.37 0.49]
# Victory [0.08 0.   0.46 0.46]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.01 0.   0.03 0.96]
# Wakanda Forever  [0.01 0.   0.01 0.98]
# Wakanda Forever  [0.02 0.   0.02 0.96]
# Wakanda Forever  [0.01 0.   0.03 0.96]
# Wakanda Forever  [0.01 0.   0.01 0.98]
# Wakanda Forever  [0.01 0.   0.02 0.97]
# Wakanda Forever  [0.04 0.   0.11 0.85]
# Wakanda Forever  [0.04 0.   0.1  0.86]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.   0.   0.12 0.88]
# Wakanda Forever  [0.   0.   0.06 0.94]
# Wakanda Forever  [0.02 0.   0.05 0.93]
# Wakanda Forever  [0.04 0.   0.09 0.87]
# Wakanda Forever  [0.04 0.   0.06 0.9 ]
# Wakanda Forever  [0.06 0.   0.06 0.88]
# Wakanda Forever  [0.28 0.   0.06 0.66]
# Wakanda Forever  [0.05 0.   0.09 0.86]
# Wakanda Forever  [0.04 0.   0.11 0.85]
# Wakanda Forever  [0.02 0.   0.12 0.86]
# Wakanda Forever  [0.04 0.   0.11 0.85]
# Wakanda Forever  [0.02 0.   0.12 0.86]
# Wakanda Forever  [0.03 0.   0.12 0.85]
# Wakanda Forever  [0.02 0.   0.14 0.84]
# Wakanda Forever  [0.   0.   0.03 0.97]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.01 0.   0.01 0.98]
# Wakanda Forever  [0.01 0.   0.02 0.97]
# Wakanda Forever  [0.02 0.   0.02 0.96]
# Wakanda Forever  [0.01 0.   0.02 0.97]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.01 0.   0.03 0.96]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.03 0.97]
# Wakanda Forever  [0.01 0.   0.05 0.94]
# Wakanda Forever  [0.01 0.   0.03 0.96]
# Wakanda Forever  [0.   0.   0.03 0.97]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.04 0.   0.11 0.85]
# Wakanda Forever  [0.27 0.   0.17 0.56]
# Wakanda Forever  [0.14 0.   0.16 0.7 ]
# Wakanda Forever  [0.07 0.   0.18 0.75]
# Wakanda Forever  [0.01 0.   0.02 0.97]
# Wakanda Forever  [0.01 0.   0.01 0.98]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.01 0.   0.15 0.84]
# Wakanda Forever  [0.05 0.   0.23 0.72]
# Wakanda Forever  [0.08 0.   0.22 0.7 ]
# Wakanda Forever  [0.06 0.   0.25 0.69]
# Wakanda Forever  [0.   0.   0.07 0.93]
# Wakanda Forever  [0.02 0.   0.04 0.94]
# Wakanda Forever  [0.02 0.   0.02 0.96]
# Wakanda Forever  [0.02 0.   0.02 0.96]
# Wakanda Forever  [0.01 0.   0.02 0.97]
# Wakanda Forever  [0.01 0.   0.02 0.97]
# Wakanda Forever  [0.01 0.   0.01 0.98]
# Wakanda Forever  [0.02 0.   0.01 0.97]
# Wakanda Forever  [0.02 0.   0.01 0.97]
# Wakanda Forever  [0.01 0.   0.02 0.97]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.01 0.   0.01 0.98]
# Wakanda Forever  [0.01 0.   0.01 0.98]
# Wakanda Forever  [0.02 0.   0.01 0.97]
# Wakanda Forever  [0.01 0.   0.02 0.97]
# Wakanda Forever  [0.01 0.   0.01 0.98]
# Wakanda Forever  [0.01 0.   0.01 0.98]
# Wakanda Forever  [0.01 0.   0.03 0.96]
# Wakanda Forever  [0.01 0.   0.01 0.98]
# Wakanda Forever  [0.   0.   0.03 0.97]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.01 0.   0.03 0.96]
# Wakanda Forever  [0.01 0.   0.03 0.96]
# Wakanda Forever  [0.01 0.   0.03 0.96]
# Wakanda Forever  [0.01 0.   0.04 0.95]
# Wakanda Forever  [0.01 0.   0.06 0.93]
# Wakanda Forever  [0.01 0.   0.05 0.94]
# Wakanda Forever  [0.01 0.   0.03 0.96]
# Wakanda Forever  [0.01 0.   0.04 0.95]
# Wakanda Forever  [0.   0.   0.03 0.97]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.   0.   0.03 0.97]
# Wakanda Forever  [0.   0.   0.03 0.97]
# Wakanda Forever  [0.   0.   0.03 0.97]
# Wakanda Forever  [0.   0.   0.04 0.96]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.   0.   0.04 0.96]
# Wakanda Forever  [0.   0.   0.04 0.96]
# Wakanda Forever  [0.   0.   0.07 0.93]
# Wakanda Forever  [0.01 0.   0.11 0.88]
# Victory [0.07 0.01 0.5  0.42]
# Victory [0.04 0.04 0.53 0.39]
# Wakanda Forever  [0.23 0.   0.12 0.65]
# Wakanda Forever  [0.11 0.   0.21 0.68]
# Wakanda Forever  [0.11 0.   0.28 0.61]
# Wakanda Forever  [0.32 0.   0.24 0.44]
# Happy [0.49 0.01 0.17 0.33]
# Wakanda Forever  [0.28 0.   0.27 0.45]
# Happy [0.47 0.   0.19 0.34]
# Victory [0.15 0.08 0.46 0.31]
# Victory [0.13 0.05 0.45 0.37]
# Wakanda Forever  [0.31 0.01 0.26 0.42]
# Happy [0.45 0.   0.23 0.32]
# Wakanda Forever  [0.02 0.   0.13 0.85]
# Wakanda Forever  [0.   0.   0.02 0.98]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.01 0.   0.07 0.92]
# Wakanda Forever  [0.04 0.   0.15 0.81]
# Wakanda Forever  [0.03 0.   0.14 0.83]
# Wakanda Forever  [0.07 0.   0.25 0.68]
# Wakanda Forever  [0.01 0.   0.12 0.87]
# Wakanda Forever  [0.   0.   0.06 0.94]
# Wakanda Forever  [0.01 0.   0.   0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0.   0.   0.01 0.99]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0. 0. 0. 1.]
# Wakanda Forever  [0.02 0.   0.07 0.91]
# Wakanda Forever  [0.01 0.   0.12 0.87]
# Wakanda Forever  [0.4  0.01 0.11 0.48]
# Wakanda Forever  [0.38 0.01 0.22 0.39]
# Victory [0.13 0.23 0.4  0.24]
# Sad [0.09 0.44 0.31 0.16]
# Sad [0.08 0.35 0.34 0.23]
# Victory [0.12 0.23 0.4  0.25]
# Victory [0.14 0.18 0.46 0.22]
# Sad [0.01 0.83 0.15 0.01]
# Sad [0.   0.89 0.1  0.01]
# Sad [0.09 0.53 0.32 0.06]
# Sad [0.07 0.47 0.38 0.08]
# Victory [0.13 0.15 0.54 0.18]
# Victory [0.33 0.02 0.45 0.2 ]
# Victory [0.31 0.03 0.42 0.24]
# Victory [0.3  0.02 0.45 0.23]
# Victory [0.2  0.08 0.49 0.23]
# Sad [0.   0.83 0.15 0.02]
# Sad [0.01 0.82 0.15 0.02]
# Sad [0.   0.86 0.12 0.02]
# Sad [0.   0.89 0.1  0.01]
# Sad [0.   0.89 0.1  0.01]
# Sad [0.02 0.79 0.18 0.01]
# Sad [0.03 0.66 0.29 0.02]
# Sad [0.   0.89 0.1  0.01]
# Sad [0.   0.89 0.1  0.01]
# Sad [0.   0.89 0.1  0.01]
# Sad [0.   0.89 0.1  0.01]
# Sad [0.   0.89 0.1  0.01]
# Sad [0.   0.88 0.11 0.01]
# Sad [0.   0.88 0.11 0.01]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.88 0.12 0.  ]
# Sad [0.   0.87 0.13 0.  ]
# Sad [0.   0.8  0.19 0.01]
# Sad [0.   0.8  0.19 0.01]
# Sad [0.02 0.74 0.23 0.01]
# Sad [0.04 0.63 0.32 0.01]
# Sad [0.04 0.57 0.37 0.02]
# Sad [0.03 0.72 0.24 0.01]
# Sad [0.02 0.77 0.19 0.02]
# Sad [0.   0.84 0.15 0.01]
# Sad [0.   0.86 0.13 0.01]
# Sad [0.   0.87 0.13 0.  ]
# Sad [0.   0.85 0.15 0.  ]
# Sad [0.01 0.82 0.16 0.01]
# Sad [0.01 0.82 0.16 0.01]
# Sad [0.01 0.77 0.21 0.01]
# Sad [0.03 0.64 0.33 0.  ]
# Sad [0.03 0.59 0.36 0.02]
# Victory [0.04 0.46 0.48 0.02]
# Victory [0.23 0.01 0.62 0.14]
# Victory [0.25 0.01 0.59 0.15]

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (405, 234)
